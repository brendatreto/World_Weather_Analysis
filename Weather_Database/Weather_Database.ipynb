# %% [markdown]
# ## Deliverable 1: Retrieve Weather Data

# %%
# Import dependencies

from citipy import citipy
import pandas as pd
import numpy as np
import json
import requests
import timeit

from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list to hold cities
cities = []

# Get nearest cities

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # Add city to city list (if unique)
    if city not in cities:
        cities.append(city)
        
# Print count to confirm 
len(cities)
# Out:
# 751

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create empty list to hold data
city_data = []

# Print beginning of loggin
print("Beginning Data Retrieval")
print("------------------------------------------------")

# Set counters
record_count = 1
set_count = 1

# loop through cities in the list
for i, city in enumerate(cities):
    
    if (i % 50 == 0 and i >=50):
        set_count +=1
        record_count = 1
    city_url = url + "&q=" + city.replace(" ", "+")
    
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    
    # Add 1 to record count
    
    record_count +=1
    
    # Run API request
    try:
        city_weather = requests.get(city_url).json()
        # Parse needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
    except:
        print("City not found. Skipping...")
        pass
        

    
# Data complete
print("--------------------------------------------------")
print("Data Retrieval Complete")
print("--------------------------------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | bud
# Processing Record 3 of Set 1 | sao joao da barra
# Processing Record 4 of Set 1 | vila velha
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | cabo san lucas
# Processing Record 7 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | hilo
# Processing Record 10 of Set 1 | kibala
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | banjarmasin
# Processing Record 13 of Set 1 | chilca
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | himora
# City not found. Skipping...
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | houma
# Processing Record 21 of Set 1 | rocha
# Processing Record 22 of Set 1 | fortuna
# Processing Record 23 of Set 1 | emerald
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | terney
# Processing Record 26 of Set 1 | voskresenskoye
# Processing Record 27 of Set 1 | nikolskoye
# Processing Record 28 of Set 1 | ribeira grande
# Processing Record 29 of Set 1 | holme
# Processing Record 30 of Set 1 | lompoc
# Processing Record 31 of Set 1 | esperance
# Processing Record 32 of Set 1 | yellowknife
# Processing Record 33 of Set 1 | cartagena
# Processing Record 34 of Set 1 | portage
# Processing Record 35 of Set 1 | alyangula
# Processing Record 36 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 1 | morondava
# Processing Record 38 of Set 1 | boende
# Processing Record 39 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 1 | tasiilaq
# Processing Record 41 of Set 1 | castro
# Processing Record 42 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 1 | havre-saint-pierre
# Processing Record 44 of Set 1 | phrai bung
# City not found. Skipping...
# Processing Record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 1 | port-gentil
# Processing Record 47 of Set 1 | bereda
# Processing Record 48 of Set 1 | westport
# Processing Record 49 of Set 1 | dingle
# Processing Record 50 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 2 | severo-kurilsk
# Processing Record 2 of Set 2 | san jose
# Processing Record 3 of Set 2 | kodiak
# Processing Record 4 of Set 2 | quelimane
# Processing Record 5 of Set 2 | arraial do cabo
# Processing Record 6 of Set 2 | torbay
# Processing Record 7 of Set 2 | sorong
# Processing Record 8 of Set 2 | calama
# Processing Record 9 of Set 2 | kattivakkam
# Processing Record 10 of Set 2 | namatanai
# Processing Record 11 of Set 2 | mataura
# Processing Record 12 of Set 2 | sao miguel do araguaia
# Processing Record 13 of Set 2 | kaitangata
# Processing Record 14 of Set 2 | mount gambier
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | upernavik
# Processing Record 17 of Set 2 | bredasdorp
# Processing Record 18 of Set 2 | carnarvon
# Processing Record 19 of Set 2 | aquiraz
# Processing Record 20 of Set 2 | hithadhoo
# Processing Record 21 of Set 2 | chokurdakh
# Processing Record 22 of Set 2 | saint-philippe
# Processing Record 23 of Set 2 | tuktoyaktuk
# Processing Record 24 of Set 2 | mount isa
# Processing Record 25 of Set 2 | kalmunai
# Processing Record 26 of Set 2 | airai
# Processing Record 27 of Set 2 | chauk
# Processing Record 28 of Set 2 | bengkulu
# Processing Record 29 of Set 2 | lapeer
# Processing Record 30 of Set 2 | avarua
# Processing Record 31 of Set 2 | cidreira
# Processing Record 32 of Set 2 | calbuco
# Processing Record 33 of Set 2 | provideniya
# Processing Record 34 of Set 2 | port hardy
# Processing Record 35 of Set 2 | mareeba
# Processing Record 36 of Set 2 | bandarbeyla
# Processing Record 37 of Set 2 | walvis bay
# Processing Record 38 of Set 2 | bethel
# Processing Record 39 of Set 2 | kamaishi
# Processing Record 40 of Set 2 | busselton
# Processing Record 41 of Set 2 | robertson
# Processing Record 42 of Set 2 | jamestown
# Processing Record 43 of Set 2 | touros
# Processing Record 44 of Set 2 | ponta do sol
# Processing Record 45 of Set 2 | anqing
# Processing Record 46 of Set 2 | muros
# Processing Record 47 of Set 2 | robertsport
# Processing Record 48 of Set 2 | lagoa
# Processing Record 49 of Set 2 | kavaratti
# Processing Record 50 of Set 2 | jalu
# Processing Record 1 of Set 3 | iida
# Processing Record 2 of Set 3 | granada
# Processing Record 3 of Set 3 | krokos
# Processing Record 4 of Set 3 | mgandu
# Processing Record 5 of Set 3 | broome
# Processing Record 6 of Set 3 | bubaque
# Processing Record 7 of Set 3 | georgetown
# Processing Record 8 of Set 3 | longyearbyen
# Processing Record 9 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 3 | codrington
# Processing Record 11 of Set 3 | gat
# Processing Record 12 of Set 3 | pevek
# Processing Record 13 of Set 3 | kichera
# Processing Record 14 of Set 3 | hay river
# Processing Record 15 of Set 3 | fomboni
# Processing Record 16 of Set 3 | mbanza-ngungu
# Processing Record 17 of Set 3 | fare
# Processing Record 18 of Set 3 | hobart
# Processing Record 19 of Set 3 | puerto ayora
# Processing Record 20 of Set 3 | forbes
# Processing Record 21 of Set 3 | aklavik
# Processing Record 22 of Set 3 | geraldton
# Processing Record 23 of Set 3 | vanavara
# Processing Record 24 of Set 3 | algiers
# Processing Record 25 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 26 of Set 3 | port augusta
# Processing Record 27 of Set 3 | madang
# Processing Record 28 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 3 | mar del plata
# Processing Record 30 of Set 3 | launceston
# Processing Record 31 of Set 3 | maceio
# Processing Record 32 of Set 3 | gouloure
# Processing Record 33 of Set 3 | portland
# Processing Record 34 of Set 3 | vestmannaeyjar
# Processing Record 35 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 3 | victoria
# Processing Record 37 of Set 3 | montlucon
# Processing Record 38 of Set 3 | yirol
# City not found. Skipping...
# Processing Record 39 of Set 3 | telma
# Processing Record 40 of Set 3 | stantsionno-oyashinskiy
# Processing Record 41 of Set 3 | manggar
# Processing Record 42 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 43 of Set 3 | dikson
# Processing Record 44 of Set 3 | beloha
# Processing Record 45 of Set 3 | qaanaaq
# Processing Record 46 of Set 3 | souillac
# Processing Record 47 of Set 3 | higuey
# City not found. Skipping...
# Processing Record 48 of Set 3 | novikovo
# Processing Record 49 of Set 3 | lugoba
# Processing Record 50 of Set 3 | saint george
# Processing Record 1 of Set 4 | college
# Processing Record 2 of Set 4 | marsa matruh
# Processing Record 3 of Set 4 | butaritari
# Processing Record 4 of Set 4 | karratha
# Processing Record 5 of Set 4 | redlands
# Processing Record 6 of Set 4 | dubbo
# Processing Record 7 of Set 4 | taburi
# City not found. Skipping...
# Processing Record 8 of Set 4 | new norfolk
# Processing Record 9 of Set 4 | evensk
# Processing Record 10 of Set 4 | sambava
# Processing Record 11 of Set 4 | port alfred
# Processing Record 12 of Set 4 | srednekolymsk
# Processing Record 13 of Set 4 | la ronge
# Processing Record 14 of Set 4 | shache
# Processing Record 15 of Set 4 | swan hill
# Processing Record 16 of Set 4 | alvaraes
# Processing Record 17 of Set 4 | surt
# Processing Record 18 of Set 4 | komsomolskiy
# Processing Record 19 of Set 4 | beyneu
# Processing Record 20 of Set 4 | bilma
# Processing Record 21 of Set 4 | lorengau
# Processing Record 22 of Set 4 | sao filipe
# Processing Record 23 of Set 4 | kisangani
# Processing Record 24 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 25 of Set 4 | lebu
# Processing Record 26 of Set 4 | narsaq
# Processing Record 27 of Set 4 | vardo
# Processing Record 28 of Set 4 | kruisfontein
# Processing Record 29 of Set 4 | kholmogory
# Processing Record 30 of Set 4 | yurty
# Processing Record 31 of Set 4 | itaunja
# Processing Record 32 of Set 4 | gospic
# Processing Record 33 of Set 4 | gemena
# Processing Record 34 of Set 4 | cuiluan
# Processing Record 35 of Set 4 | tuatapere
# Processing Record 36 of Set 4 | awjilah
# Processing Record 37 of Set 4 | arcos de la frontera
# Processing Record 38 of Set 4 | general roca
# Processing Record 39 of Set 4 | khatanga
# Processing Record 40 of Set 4 | maniitsoq
# Processing Record 41 of Set 4 | auki
# Processing Record 42 of Set 4 | namibe
# Processing Record 43 of Set 4 | muisne
# Processing Record 44 of Set 4 | avera
# Processing Record 45 of Set 4 | east london
# Processing Record 46 of Set 4 | luderitz
# Processing Record 47 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 4 | asau
# Processing Record 49 of Set 4 | orsha
# Processing Record 50 of Set 4 | cherskiy
# Processing Record 1 of Set 5 | birin
# Processing Record 2 of Set 5 | mahanje
# Processing Record 3 of Set 5 | kyshtovka
# Processing Record 4 of Set 5 | katsuura
# Processing Record 5 of Set 5 | kahone
# Processing Record 6 of Set 5 | bethal
# Processing Record 7 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 5 | udachnyy
# Processing Record 9 of Set 5 | tiksi
# Processing Record 10 of Set 5 | hovd
# Processing Record 11 of Set 5 | saldanha
# Processing Record 12 of Set 5 | yuanping
# Processing Record 13 of Set 5 | trelleborg
# Processing Record 14 of Set 5 | coihaique
# Processing Record 15 of Set 5 | waipawa
# Processing Record 16 of Set 5 | tanshui
# City not found. Skipping...
# Processing Record 17 of Set 5 | sungaipenuh
# Processing Record 18 of Set 5 | gravdal
# Processing Record 19 of Set 5 | leningradskiy
# Processing Record 20 of Set 5 | levelland
# Processing Record 21 of Set 5 | kargasok
# Processing Record 22 of Set 5 | bowen
# Processing Record 23 of Set 5 | alekseyevsk
# Processing Record 24 of Set 5 | fukue
# Processing Record 25 of Set 5 | port elizabeth
# Processing Record 26 of Set 5 | bambous virieux
# Processing Record 27 of Set 5 | taua
# Processing Record 28 of Set 5 | champerico
# Processing Record 29 of Set 5 | thurles
# Processing Record 30 of Set 5 | nantucket
# Processing Record 31 of Set 5 | chapleau
# Processing Record 32 of Set 5 | lasa
# Processing Record 33 of Set 5 | tautira
# Processing Record 34 of Set 5 | baghdad
# Processing Record 35 of Set 5 | mwinilunga
# Processing Record 36 of Set 5 | kupang
# Processing Record 37 of Set 5 | nome
# Processing Record 38 of Set 5 | metro
# Processing Record 39 of Set 5 | vanderhoof
# Processing Record 40 of Set 5 | guerrero negro
# Processing Record 41 of Set 5 | ilulissat
# Processing Record 42 of Set 5 | vila franca do campo
# Processing Record 43 of Set 5 | comodoro rivadavia
# Processing Record 44 of Set 5 | port blair
# Processing Record 45 of Set 5 | mahebourg
# Processing Record 46 of Set 5 | sangar
# Processing Record 47 of Set 5 | sola
# Processing Record 48 of Set 5 | salalah
# Processing Record 49 of Set 5 | at-bashi
# Processing Record 50 of Set 5 | rio grande
# Processing Record 1 of Set 6 | guarapari
# Processing Record 2 of Set 6 | siparia
# Processing Record 3 of Set 6 | faya
# Processing Record 4 of Set 6 | harper
# Processing Record 5 of Set 6 | sitka
# Processing Record 6 of Set 6 | itacare
# Processing Record 7 of Set 6 | lazo
# Processing Record 8 of Set 6 | lydenburg
# Processing Record 9 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 10 of Set 6 | malmesbury
# Processing Record 11 of Set 6 | clyde river
# Processing Record 12 of Set 6 | nabire
# Processing Record 13 of Set 6 | hasaki
# Processing Record 14 of Set 6 | hereford
# Processing Record 15 of Set 6 | porto novo
# Processing Record 16 of Set 6 | nuuk
# Processing Record 17 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 18 of Set 6 | marfino
# Processing Record 19 of Set 6 | martinsburg
# Processing Record 20 of Set 6 | roma
# Processing Record 21 of Set 6 | royal tunbridge wells
# Processing Record 22 of Set 6 | kavieng
# Processing Record 23 of Set 6 | dhadar
# Processing Record 24 of Set 6 | alibag
# Processing Record 25 of Set 6 | alice springs
# Processing Record 26 of Set 6 | san patricio
# Processing Record 27 of Set 6 | hualmay
# Processing Record 28 of Set 6 | kangaatsiaq
# Processing Record 29 of Set 6 | newport
# Processing Record 30 of Set 6 | ust-tsilma
# Processing Record 31 of Set 6 | lima
# Processing Record 32 of Set 6 | kampot
# Processing Record 33 of Set 6 | puqi
# Processing Record 34 of Set 6 | white rock
# Processing Record 35 of Set 6 | kirakira
# Processing Record 36 of Set 6 | mutsu
# Processing Record 37 of Set 6 | brae
# Processing Record 38 of Set 6 | the valley
# Processing Record 39 of Set 6 | constitucion
# Processing Record 40 of Set 6 | rio gallegos
# Processing Record 41 of Set 6 | kyzyl-suu
# Processing Record 42 of Set 6 | kon tum
# Processing Record 43 of Set 6 | vostok
# Processing Record 44 of Set 6 | tiznit
# Processing Record 45 of Set 6 | el tigre
# Processing Record 46 of Set 6 | korla
# Processing Record 47 of Set 6 | minab
# Processing Record 48 of Set 6 | birao
# Processing Record 49 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 6 | honningsvag
# Processing Record 1 of Set 7 | lahaina
# Processing Record 2 of Set 7 | san andres
# Processing Record 3 of Set 7 | huarmey
# Processing Record 4 of Set 7 | vanimo
# Processing Record 5 of Set 7 | teluk nibung
# Processing Record 6 of Set 7 | acarau
# Processing Record 7 of Set 7 | saskylakh
# Processing Record 8 of Set 7 | orebro
# Processing Record 9 of Set 7 | vilyuysk
# Processing Record 10 of Set 7 | campagna
# Processing Record 11 of Set 7 | aykhal
# Processing Record 12 of Set 7 | klaksvik
# Processing Record 13 of Set 7 | ancud
# Processing Record 14 of Set 7 | pochutla
# Processing Record 15 of Set 7 | macenta
# Processing Record 16 of Set 7 | norman wells
# Processing Record 17 of Set 7 | yokadouma
# Processing Record 18 of Set 7 | khasan
# Processing Record 19 of Set 7 | jiangkou
# Processing Record 20 of Set 7 | sorland
# Processing Record 21 of Set 7 | turukhansk
# Processing Record 22 of Set 7 | flin flon
# Processing Record 23 of Set 7 | baruun-urt
# Processing Record 24 of Set 7 | payakumbuh
# Processing Record 25 of Set 7 | isangel
# Processing Record 26 of Set 7 | china
# Processing Record 27 of Set 7 | ozinki
# Processing Record 28 of Set 7 | saint-augustin
# Processing Record 29 of Set 7 | bilibino
# Processing Record 30 of Set 7 | winona
# Processing Record 31 of Set 7 | bathsheba
# Processing Record 32 of Set 7 | atar
# Processing Record 33 of Set 7 | san ignacio
# Processing Record 34 of Set 7 | yagodnoye
# Processing Record 35 of Set 7 | homer
# Processing Record 36 of Set 7 | owerri
# Processing Record 37 of Set 7 | collie
# Processing Record 38 of Set 7 | faanui
# Processing Record 39 of Set 7 | grandview
# Processing Record 40 of Set 7 | ntungamo
# Processing Record 41 of Set 7 | lavrentiya
# Processing Record 42 of Set 7 | alofi
# Processing Record 43 of Set 7 | burica
# City not found. Skipping...
# Processing Record 44 of Set 7 | hirara
# Processing Record 45 of Set 7 | lazaro cardenas
# Processing Record 46 of Set 7 | mehamn
# Processing Record 47 of Set 7 | saint-marc
# Processing Record 48 of Set 7 | pucallpa
# Processing Record 49 of Set 7 | najran
# Processing Record 50 of Set 7 | sayyan
# Processing Record 1 of Set 8 | eureka
# Processing Record 2 of Set 8 | rovira
# Processing Record 3 of Set 8 | saint anthony
# Processing Record 4 of Set 8 | viedma
# Processing Record 5 of Set 8 | saint-georges
# Processing Record 6 of Set 8 | laguna
# Processing Record 7 of Set 8 | sisimiut
# Processing Record 8 of Set 8 | adrar
# Processing Record 9 of Set 8 | kanye
# Processing Record 10 of Set 8 | gizo
# Processing Record 11 of Set 8 | san antonio
# Processing Record 12 of Set 8 | yar-sale
# Processing Record 13 of Set 8 | grindavik
# Processing Record 14 of Set 8 | sakakah
# Processing Record 15 of Set 8 | vila
# Processing Record 16 of Set 8 | garca
# Processing Record 17 of Set 8 | solnechnyy
# Processing Record 18 of Set 8 | praia
# Processing Record 19 of Set 8 | fort saint james
# Processing Record 20 of Set 8 | yanam
# Processing Record 21 of Set 8 | yulara
# Processing Record 22 of Set 8 | safaga
# Processing Record 23 of Set 8 | lucea
# Processing Record 24 of Set 8 | powassan
# Processing Record 25 of Set 8 | dhidhdhoo
# Processing Record 26 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 27 of Set 8 | thompson
# Processing Record 28 of Set 8 | tazovskiy
# Processing Record 29 of Set 8 | lakselv
# Processing Record 30 of Set 8 | tayu
# Processing Record 31 of Set 8 | caraballeda
# Processing Record 32 of Set 8 | cabedelo
# Processing Record 33 of Set 8 | nara
# Processing Record 34 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 35 of Set 8 | oak ridge
# Processing Record 36 of Set 8 | la orilla
# Processing Record 37 of Set 8 | dingli
# Processing Record 38 of Set 8 | san cristobal
# Processing Record 39 of Set 8 | bardiyah
# Processing Record 40 of Set 8 | taoudenni
# Processing Record 41 of Set 8 | santarem
# Processing Record 42 of Set 8 | tual
# Processing Record 43 of Set 8 | haines junction
# Processing Record 44 of Set 8 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 45 of Set 8 | greensburg
# Processing Record 46 of Set 8 | high level
# Processing Record 47 of Set 8 | mackay
# Processing Record 48 of Set 8 | waharoa
# Processing Record 49 of Set 8 | bouna
# Processing Record 50 of Set 8 | posse
# Processing Record 1 of Set 9 | tuy hoa
# Processing Record 2 of Set 9 | elko
# Processing Record 3 of Set 9 | sarkand
# Processing Record 4 of Set 9 | kerteh
# City not found. Skipping...
# Processing Record 5 of Set 9 | chuy
# Processing Record 6 of Set 9 | hit
# Processing Record 7 of Set 9 | araguatins
# City not found. Skipping...
# Processing Record 8 of Set 9 | bekwai
# Processing Record 9 of Set 9 | kunda
# Processing Record 10 of Set 9 | ambilobe
# Processing Record 11 of Set 9 | pudozh
# Processing Record 12 of Set 9 | husavik
# Processing Record 13 of Set 9 | lodingen
# Processing Record 14 of Set 9 | port lincoln
# Processing Record 15 of Set 9 | bloomington
# Processing Record 16 of Set 9 | hyderabad
# Processing Record 17 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 9 | rawson
# Processing Record 19 of Set 9 | taiobeiras
# Processing Record 20 of Set 9 | kulhudhuffushi
# Processing Record 21 of Set 9 | oistins
# Processing Record 22 of Set 9 | beringovskiy
# Processing Record 23 of Set 9 | tiarei
# Processing Record 24 of Set 9 | gua musang
# Processing Record 25 of Set 9 | ilhabela
# Processing Record 26 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 9 | tubuala
# Processing Record 28 of Set 9 | laguna de duero
# Processing Record 29 of Set 9 | northfield
# Processing Record 30 of Set 9 | tessalit
# Processing Record 31 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 9 | tura
# Processing Record 33 of Set 9 | aksu
# Processing Record 34 of Set 9 | sinnamary
# Processing Record 35 of Set 9 | talnakh
# Processing Record 36 of Set 9 | aojiang
# Processing Record 37 of Set 9 | jabinyanah
# Processing Record 38 of Set 9 | kabalo
# Processing Record 39 of Set 9 | achacachi
# Processing Record 40 of Set 9 | kudahuvadhoo
# Processing Record 41 of Set 9 | cockburn town
# Processing Record 42 of Set 9 | port hedland
# Processing Record 43 of Set 9 | murdochville
# Processing Record 44 of Set 9 | kungurtug
# Processing Record 45 of Set 9 | carros
# Processing Record 46 of Set 9 | iqaluit
# Processing Record 47 of Set 9 | northam
# Processing Record 48 of Set 9 | coquimbo
# Processing Record 49 of Set 9 | vestmanna
# Processing Record 50 of Set 9 | ensley
# Processing Record 1 of Set 10 | coahuayana
# Processing Record 2 of Set 10 | yankton
# Processing Record 3 of Set 10 | hokitika
# Processing Record 4 of Set 10 | dudinka
# Processing Record 5 of Set 10 | makurdi
# Processing Record 6 of Set 10 | mindelo
# Processing Record 7 of Set 10 | gornorechenskiy
# Processing Record 8 of Set 10 | chumikan
# Processing Record 9 of Set 10 | bac lieu
# Processing Record 10 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 10 | panama city
# Processing Record 12 of Set 10 | marienburg
# Processing Record 13 of Set 10 | veraval
# Processing Record 14 of Set 10 | ponta delgada
# Processing Record 15 of Set 10 | itarema
# Processing Record 16 of Set 10 | necochea
# Processing Record 17 of Set 10 | xuanhua
# Processing Record 18 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 19 of Set 10 | lewisporte
# Processing Record 20 of Set 10 | banikoara
# Processing Record 21 of Set 10 | te anau
# Processing Record 22 of Set 10 | severo-yeniseyskiy
# Processing Record 23 of Set 10 | ures
# Processing Record 24 of Set 10 | deh rawud
# City not found. Skipping...
# Processing Record 25 of Set 10 | urengoy
# Processing Record 26 of Set 10 | quatre cocos
# Processing Record 27 of Set 10 | lazarev
# Processing Record 28 of Set 10 | diffa
# Processing Record 29 of Set 10 | vadakku valliyur
# Processing Record 30 of Set 10 | cap-aux-meules
# Processing Record 31 of Set 10 | usinsk
# Processing Record 32 of Set 10 | sulangan
# Processing Record 33 of Set 10 | nogliki
# Processing Record 34 of Set 10 | suluq
# Processing Record 35 of Set 10 | fort nelson
# Processing Record 36 of Set 10 | keflavik
# Processing Record 37 of Set 10 | inhambane
# Processing Record 38 of Set 10 | yazman
# Processing Record 39 of Set 10 | general pico
# Processing Record 40 of Set 10 | boa vista
# Processing Record 41 of Set 10 | mudgee
# Processing Record 42 of Set 10 | iskateley
# Processing Record 43 of Set 10 | fairbanks
# Processing Record 44 of Set 10 | puri
# Processing Record 45 of Set 10 | anadyr
# Processing Record 46 of Set 10 | otane
# Processing Record 47 of Set 10 | arlit
# Processing Record 48 of Set 10 | yuksekova
# Processing Record 49 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 10 | jeremie
# Processing Record 1 of Set 11 | sitrah
# Processing Record 2 of Set 11 | mpanda
# Processing Record 3 of Set 11 | tilichiki
# Processing Record 4 of Set 11 | ishigaki
# Processing Record 5 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 6 of Set 11 | pacatuba
# Processing Record 7 of Set 11 | altay
# Processing Record 8 of Set 11 | novoraychikhinsk
# Processing Record 9 of Set 11 | liberal
# Processing Record 10 of Set 11 | nouadhibou
# Processing Record 11 of Set 11 | hatillo
# Processing Record 12 of Set 11 | adamovka
# Processing Record 13 of Set 11 | xique-xique
# Processing Record 14 of Set 11 | owando
# Processing Record 15 of Set 11 | xiangxiang
# Processing Record 16 of Set 11 | yining
# Processing Record 17 of Set 11 | hamilton
# Processing Record 18 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 11 | great bend
# Processing Record 20 of Set 11 | yenagoa
# Processing Record 21 of Set 11 | berlevag
# Processing Record 22 of Set 11 | kota kinabalu
# Processing Record 23 of Set 11 | byron bay
# Processing Record 24 of Set 11 | te karaka
# Processing Record 25 of Set 11 | shingu
# Processing Record 26 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 11 | kahului
# Processing Record 28 of Set 11 | cotonou
# Processing Record 29 of Set 11 | lundazi
# Processing Record 30 of Set 11 | pahalgam
# Processing Record 31 of Set 11 | naze
# Processing Record 32 of Set 11 | cumaribo
# City not found. Skipping...
# Processing Record 33 of Set 11 | vitimskiy
# City not found. Skipping...
# Processing Record 34 of Set 11 | meulaboh
# Processing Record 35 of Set 11 | ranapur
# Processing Record 36 of Set 11 | tecoanapa
# Processing Record 37 of Set 11 | riyaq
# City not found. Skipping...
# Processing Record 38 of Set 11 | peace river
# Processing Record 39 of Set 11 | shihezi
# Processing Record 40 of Set 11 | nanortalik
# Processing Record 41 of Set 11 | meadela
# Processing Record 42 of Set 11 | jurm
# Processing Record 43 of Set 11 | okhotsk
# Processing Record 44 of Set 11 | trelew
# Processing Record 45 of Set 11 | ourinhos
# Processing Record 46 of Set 11 | saint john
# Processing Record 47 of Set 11 | springfield
# Processing Record 48 of Set 11 | khormuj
# City not found. Skipping...
# Processing Record 49 of Set 11 | tignere
# Processing Record 50 of Set 11 | lodwar
# Processing Record 1 of Set 12 | katangli
# Processing Record 2 of Set 12 | dunedin
# Processing Record 3 of Set 12 | bontang
# Processing Record 4 of Set 12 | rolim de moura
# City not found. Skipping...
# Processing Record 5 of Set 12 | maromitsa
# Processing Record 6 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 7 of Set 12 | bure
# Processing Record 8 of Set 12 | amapa
# Processing Record 9 of Set 12 | nakhodka
# Processing Record 10 of Set 12 | pafos
# Processing Record 11 of Set 12 | westpunt
# City not found. Skipping...
# Processing Record 12 of Set 12 | inuvik
# Processing Record 13 of Set 12 | presidencia roque saenz pena
# Processing Record 14 of Set 12 | los llanos de aridane
# Processing Record 15 of Set 12 | hami
# Processing Record 16 of Set 12 | belozernyy
# Processing Record 17 of Set 12 | mae hong son
# Processing Record 18 of Set 12 | carutapera
# Processing Record 19 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 20 of Set 12 | meiktila
# Processing Record 21 of Set 12 | sorgues
# Processing Record 22 of Set 12 | conceicao do coite
# Processing Record 23 of Set 12 | gazli
# Processing Record 24 of Set 12 | larsnes
# Processing Record 25 of Set 12 | eyl
# Processing Record 26 of Set 12 | norrtalje
# Processing Record 27 of Set 12 | tashara
# Processing Record 28 of Set 12 | diamantino
# Processing Record 29 of Set 12 | zhigansk
# Processing Record 30 of Set 12 | ulladulla
# Processing Record 31 of Set 12 | nizhniy tsasuchey
# Processing Record 32 of Set 12 | ixtapa
# Processing Record 33 of Set 12 | krasnoselkup
# Processing Record 34 of Set 12 | flinders
# Processing Record 35 of Set 12 | ayan
# Processing Record 36 of Set 12 | houston
# Processing Record 37 of Set 12 | iturama
# Processing Record 38 of Set 12 | kununurra
# Processing Record 39 of Set 12 | cayenne
# Processing Record 40 of Set 12 | pechenga
# Processing Record 41 of Set 12 | fredericton
# Processing Record 42 of Set 12 | ayame
# Processing Record 43 of Set 12 | patacamaya
# Processing Record 44 of Set 12 | aljezur
# Processing Record 45 of Set 12 | copiapo
# Processing Record 46 of Set 12 | chateaubelair
# Processing Record 47 of Set 12 | strezhevoy
# Processing Record 48 of Set 12 | abu kamal
# Processing Record 49 of Set 12 | shenjiamen
# Processing Record 50 of Set 12 | thinadhoo
# Processing Record 1 of Set 13 | qaqortoq
# Processing Record 2 of Set 13 | mildura
# Processing Record 3 of Set 13 | cumberland
# Processing Record 4 of Set 13 | nouakchott
# Processing Record 5 of Set 13 | mango
# Processing Record 6 of Set 13 | lewistown
# Processing Record 7 of Set 13 | mecca
# Processing Record 8 of Set 13 | brawley
# Processing Record 9 of Set 13 | port keats
# Processing Record 10 of Set 13 | mahibadhoo
# Processing Record 11 of Set 13 | mandalgovi
# Processing Record 12 of Set 13 | raga
# Processing Record 13 of Set 13 | esfarayen
# Processing Record 14 of Set 13 | daru
# Processing Record 15 of Set 13 | fountain valley
# Processing Record 16 of Set 13 | melenki
# Processing Record 17 of Set 13 | havoysund
# Processing Record 18 of Set 13 | arica
# Processing Record 19 of Set 13 | santa rosa
# Processing Record 20 of Set 13 | kysyl-syr
# Processing Record 21 of Set 13 | tabuk
# Processing Record 22 of Set 13 | jumla
# Processing Record 23 of Set 13 | sioux lookout
# Processing Record 24 of Set 13 | zyryanka
# Processing Record 25 of Set 13 | simao
# Processing Record 26 of Set 13 | basar
# Processing Record 27 of Set 13 | hobyo
# Processing Record 28 of Set 13 | nago
# Processing Record 29 of Set 13 | nemuro
# Processing Record 30 of Set 13 | teguldet
# Processing Record 31 of Set 13 | sistranda
# Processing Record 32 of Set 13 | suoyarvi
# Processing Record 33 of Set 13 | kimbe
# Processing Record 34 of Set 13 | kushiro
# Processing Record 35 of Set 13 | ninghai
# Processing Record 36 of Set 13 | the pas
# Processing Record 37 of Set 13 | elat
# Processing Record 38 of Set 13 | popondetta
# Processing Record 39 of Set 13 | abeche
# Processing Record 40 of Set 13 | tall kayf
# Processing Record 41 of Set 13 | kizema
# Processing Record 42 of Set 13 | mulege
# Processing Record 43 of Set 13 | manaus
# Processing Record 44 of Set 13 | makakilo city
# Processing Record 45 of Set 13 | japura
# Processing Record 46 of Set 13 | punta alta
# Processing Record 47 of Set 13 | maningrida
# Processing Record 48 of Set 13 | santa cruz
# Processing Record 49 of Set 13 | opochka
# Processing Record 50 of Set 13 | ekhabi
# Processing Record 1 of Set 14 | kismayo
# Processing Record 2 of Set 14 | catuday
# Processing Record 3 of Set 14 | malakal
# Processing Record 4 of Set 14 | ondjiva
# Processing Record 5 of Set 14 | amalapuram
# Processing Record 6 of Set 14 | juli
# Processing Record 7 of Set 14 | akalkot
# Processing Record 8 of Set 14 | fort frances
# Processing Record 9 of Set 14 | riyadh
# Processing Record 10 of Set 14 | george town
# Processing Record 11 of Set 14 | lethem
# Processing Record 12 of Set 14 | srandakan
# Processing Record 13 of Set 14 | pangai
# Processing Record 14 of Set 14 | oussouye
# Processing Record 15 of Set 14 | dwarka
# Processing Record 16 of Set 14 | zheleznodorozhnyy
# Processing Record 17 of Set 14 | mogadishu
# Processing Record 18 of Set 14 | pacific grove
# Processing Record 19 of Set 14 | mezen
# Processing Record 20 of Set 14 | rafai
# Processing Record 21 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 22 of Set 14 | hastings
# Processing Record 23 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 24 of Set 14 | lugovskoy
# Processing Record 25 of Set 14 | mineiros
# Processing Record 26 of Set 14 | umm lajj
# Processing Record 27 of Set 14 | poum
# Processing Record 28 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 29 of Set 14 | goderich
# Processing Record 30 of Set 14 | khagrachari
# City not found. Skipping...
# Processing Record 31 of Set 14 | mazagao
# Processing Record 32 of Set 14 | lamu
# Processing Record 33 of Set 14 | caravelas
# Processing Record 34 of Set 14 | antalaha
# Processing Record 35 of Set 14 | moramanga
# Processing Record 36 of Set 14 | katherine
# Processing Record 37 of Set 14 | lalomanu
# City not found. Skipping...
# Processing Record 38 of Set 14 | topchanchi
# Processing Record 39 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 14 | livingston
# Processing Record 41 of Set 14 | alta floresta
# Processing Record 42 of Set 14 | samandag
# Processing Record 43 of Set 14 | amecameca
# Processing Record 44 of Set 14 | ostrovnoy
# Processing Record 45 of Set 14 | nacogdoches
# Processing Record 46 of Set 14 | luwuk
# Processing Record 47 of Set 14 | miraflores
# Processing Record 48 of Set 14 | rabo de peixe
# Processing Record 49 of Set 14 | shiraz
# Processing Record 50 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 15 | koslan
# Processing Record 2 of Set 15 | claremorris
# Processing Record 3 of Set 15 | langangen
# City not found. Skipping...
# Processing Record 4 of Set 15 | zlobin
# Processing Record 5 of Set 15 | maghama
# City not found. Skipping...
# Processing Record 6 of Set 15 | malinyi
# Processing Record 7 of Set 15 | margate
# Processing Record 8 of Set 15 | deputatskiy
# Processing Record 9 of Set 15 | zhelyabovka
# Processing Record 10 of Set 15 | chabahar
# Processing Record 11 of Set 15 | muzhi
# Processing Record 12 of Set 15 | garmsar
# Processing Record 13 of Set 15 | araouane
# Processing Record 14 of Set 15 | hearst
# Processing Record 15 of Set 15 | kangalassy
# Processing Record 16 of Set 15 | olafsvik
# Processing Record 17 of Set 15 | sabha
# Processing Record 18 of Set 15 | okato
# Processing Record 19 of Set 15 | ilo
# Processing Record 20 of Set 15 | emborion
# Processing Record 21 of Set 15 | oosterhout
# Processing Record 22 of Set 15 | slonim
# Processing Record 23 of Set 15 | inirida
# Processing Record 24 of Set 15 | neiafu
# Processing Record 25 of Set 15 | abu zabad
# Processing Record 26 of Set 15 | yaan
# Processing Record 27 of Set 15 | madimba
# Processing Record 28 of Set 15 | samarai
# Processing Record 29 of Set 15 | escondido
# Processing Record 30 of Set 15 | pisco
# Processing Record 31 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 15 | yatou
# Processing Record 33 of Set 15 | goba
# Processing Record 34 of Set 15 | inta
# Processing Record 35 of Set 15 | macaboboni
# City not found. Skipping...
# Processing Record 36 of Set 15 | senneterre
# Processing Record 37 of Set 15 | petatlan
# Processing Record 38 of Set 15 | palmares do sul
# Processing Record 39 of Set 15 | farafangana
# Processing Record 40 of Set 15 | kenai
# Processing Record 41 of Set 15 | santiago de cao
# Processing Record 42 of Set 15 | ilovlya
# Processing Record 43 of Set 15 | aras
# Processing Record 44 of Set 15 | mahajanga
# Processing Record 45 of Set 15 | grand gaube
# Processing Record 46 of Set 15 | andenes
# Processing Record 47 of Set 15 | lesozavodsk
# Processing Record 48 of Set 15 | igurubi
# Processing Record 49 of Set 15 | yumen
# Processing Record 50 of Set 15 | chiredzi
# Processing Record 1 of Set 16 | goure
# --------------------------------------------------
# Data Retrieval Complete
# --------------------------------------------------

# %%
len(city_data)
# Out:
# 694

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Ushuaia      AR -54.8000  -68.3000     69.46        49
# 1                Bud      US  39.4470  -86.1758     30.67        66
# 2  Sao Joao Da Barra      BR -21.6403  -41.0511     87.89        80
# 3         Vila Velha      BR -20.3297  -40.2925     85.95        73
# 4             Barrow      US  71.2906 -156.7887    -27.38        62
#
#    Cloudiness  Wind Speed Current Description
# 0           0        8.05           clear sky
# 1          27       11.30    scattered clouds
# 2          37       15.05    scattered clouds
# 3          40       11.50    scattered clouds
# 4           0        8.05           clear sky

# %%
# Create output file (CSV)
output_data_file = "WeatherPy_Database.csv"

#Export city_data
city_data_df.to_csv(output_data_file, index_label="City_ID")
